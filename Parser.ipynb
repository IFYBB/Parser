# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://spb.cian.ru/snyat-komnatu/'
HEADERS = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36', 'accept': '*/*'}

def get_html(url, params=None):
    r = requests.get(url, headers=HEADERS, params=params)
    return r

def get_content(html):
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.find_all('div', class_='_93444fe79c--container--2Kouc _93444fe79c--link--2-ANY')
    print(items)

    """
    rooms = []
    for item in items:
        rooms.append({
            'data-mark': item.find('span', class_='class="_93444fe79c--color_primary_100--O6-gZ _93444fe79c--lineHeight_28px--3QLml _93444fe79c--fontWeight_bold--t3Ars _93444fe79c--fontSize_22px--3UVPd _93444fe79c--display_block--1eYsq _93444fe79c--text--2_SER')
        })
    print(rooms)
    """

def parse():
    html = get_html(URL)
    if html.status_code == 200:
        get_content(html.text)
    else:
        print('Error')

parse()
# Out:
# [<div class="_93444fe79c--container--2Kouc _93444fe79c--link--2-ANY" data-name="LinkArea"><a class="_93444fe79c--link--39cNw" href="https://spb.cian.ru/rent/flat/250192239/"><span class="_93444fe79c--link-area--3CWic"></span></a><div class="_93444fe79c--container--JdWD4" data-name="TitleComponent"><span class="_93444fe79c--color_primary_100--O6-gZ _93444fe79c--lineHeight_28px--3QLml _93444fe79c--fontWeight_bold--t3Ars _93444fe79c--fontSize_22px--3UVPd _93444fe79c--display_block--1eYsq _93444fe79c--text--2_SER" data-mark="OfferTitle" style="letter-spacing:normal">1 комната, 16 м², 4/5 этаж</span></div><div class="_93444fe79c--container--2h0AF _93444fe79c--container-l--5Wrcc" data-name="ContentRow"><div class="_93444fe79c--container--wQDhY" data-name="SpecialGeo"><a class="_93444fe79c--link--3ruIo" href="https://spb.cian.ru/snyat-komnatu-sankt-peterburg-metro-baltiyskaya/" target="_blank"><div class="_93444fe79c--icon--2r99s"><div class="_93444fe79c--cont--1rew5" data-name="Underground
# ...
